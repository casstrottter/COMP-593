# %% [markdown]
# <a href="https://colab.research.google.com/github/casstrottter/COMP-593/blob/main/WEEK_3_WORKING_WITH_DATABASES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 3: WORKING WITH DATABASES

# %% [markdown]
# ## Introduction
#
# During this lab, we will experiment with using a few different libararies and modules to connect to and interact with an SQLite database. After creating and configuring our testing database, we will populate it with Fake data and run some queries to see what kind of information we can retreive. For context, we will be creating RSSN, the "Really Simple Social Network".

# %% [markdown]
# ## Creating a SQLite Database
#
# We will be utilizing the `sqlite3` library to create our database file, as it offers the convienience of creating our database file automatically in the event that it cannot find an existing file at the path specified.
#
# **Before you run the below code:**
# On the left of the notebook, select the file folder icon. Then, after you run the code block, you should be able to observe the creation of the database file. If it doesn't appear, try clicking the "Refresh" button above the list of folders.

# %%
import sqlite3

#When we retreive a Connection object, a new database will be created for us if it doesn't already exist. 
myConnection = sqlite3.connect('social_network.db')
print(sqlite3.version)
# Out:
# 2.6.0

# %% [markdown]
# ## Creating a Table

# %% [markdown]
# We'll use the below code to create a table called `people` within our database.

# %%
import sqlite3

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first table:
createPeopleTable = """ CREATE TABLE IF NOT EXISTS people (
                          id integer PRIMARY KEY,
                          name text NOT NULL,
                          email text NOT NULL,
                          address text NOT NULL,
                          city text NOT NULL,
                          province text NOT NULL,
                          country text NOT NULL,
                          phone text,
                          bio text,
                          dob date NOT NULL,
                          heatmap integer,
                          created_at datetime NOT NULL,
                          updated_at datetime NOT NULL,
                          ipv4 text
                        );"""

#Now that we have the string to create our table,
#Cursor objects have an execute() method which will accept an SQL string and perform the operations described.

myCursor.execute(createPeopleTable)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('people')")
print(myCursor.fetchone())

#We use to the commit() method on the database Connection object to persist our changes
myConnection.commit()

#It is always a good idea to close a connection when it will no longer be used
myConnection.close()
# Out:
# ('id, name, email, address, city, province, country, phone, bio, dob, heatmap, created_at, updated_at, ipv4',)

# %% [markdown]
# If you received a tuple containing the names of the columns, awesome! We have successfully created our database table.
# ```
# ('id, name, email, address, city, province, country, phone, bio, created_at, updated_at',)
# ```
#
# Run the below code block to add our first entry.

# %%
import sqlite3
from pprint import pprint #Outputs data in a slightly easier to read format
from datetime import datetime #For generating dates and times

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first entry:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

"""
The ?'s are placeholders that we can fill in when we use the execute() method.
This is really handy for code reuse, as we can pass those values are variables in a tuple
Instead of hard coding them into the statement.
"""

myPerson = ("John Doe", 
            "johndoe@anon.null", 
            "123 Fake St.", 
            "Fakesville", 
            "Fakesdom", 
            "Fakopolis", 
            None, 
            None,
            "1967-09-12",
            0,
            datetime.now(), 
            datetime.now(),
            None)

myCursor.execute(addPersonQuery, myPerson)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

# If you run this code block a few times, you will see that you only have 1 entry,
# If you uncomment the below lines and run the block a few more times, you will begin to see multiple entries.
 myConnection.commit()
 myConnection.close()
# Out:
# [(1,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-11 18:43:23.912379',
#   '2021-02-11 18:43:23.912390',
#   None)]

# %% [markdown]
# # Lab Submission

# %% [markdown]
# We're going to build our experience with working with Libraries and examining documentation by populating our 'People' table with data provided to us by the `Faker` library. `Faker` is used to generate fake data and is very helpful for the rapid generation of databases for the purposes of testing. Run the two blocks below to install faker and get an idea of what it can do.

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading https://files.pythonhosted.org/packages/4e/6a/591bea01ef396a4611b2097af19aa86975ebef06a4bb571a8a25ba36cf9a/Faker-6.1.1-py3-none-any.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 10.9MB/s
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/lib/python3.6/dist-packages (from faker) (1.3)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.6/dist-packages (from faker) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)
# Installing collected packages: faker
# Successfully installed faker-6.1.1

# %%
from faker import Faker

fake = Faker()

for _ in range(10):
  print('{} || {}'.format( fake.name(), fake.job() ) )
# Out:
# Teresa Gallegos || Estate agent
# Maria Johnson || Psychiatrist
# Crystal Durham || Stage manager
# Michael Shepherd MD || Garment/textile technologist
# Christopher Marsh || Civil Service fast streamer
# Vincent Parker || Doctor, general practice
# Gloria Cochran || Interior and spatial designer
# Tina Brown || Solicitor
# David Powell || Health and safety inspector
# Mr. Brian Williams || Printmaker

# %% [markdown]
# Very cool! Faker has tons of `providers` that can all be used to populate fake data. The [list of providers](https://faker.readthedocs.io/en/stable/providers.html) in the Faker documentation will help you fill out the columns for our People table.
#
# The goal of this script is to populate the people table with 1000 entries, with the following constraints:
#
# 1. The `heatmap` column must contain a random number between `999` and `2500`
# 2. The `created_at` and `updated_at` columns must use the `datetime` object (see examples above)
# 2. Use `Faker` to generate all other fields.
#
# *Hint: Each of the methods contained in the provider can be called directly from the base Faker object, for example, one can call the `file_name()` method from `faker.providers.file` by calling `Faker().file_name()`*

# %%
import sqlite3
from faker import Faker
from datetime import datetime #For generating dates and times
from random import randint #For generating random numbers

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#To generate a Cursor object
myCursor = myConnection.cursor()

#Defining the SQL Query
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

fake = Faker()

#Loop to populate the table with 1000 entries
for person in range(1000) :
  myPerson = (fake.name() , 
            fake.ascii_email() , 
            fake.street_address() , 
            fake.city() , 
            fake.state() , 
            fake.country() , 
            fake.phone_number() , 
            fake.text() ,
            fake.date_of_birth() ,
            randint(999,2500) ,
            datetime.now() , 
            datetime.now() ,
            fake.ipv4() )

  myCursor.execute(addPersonQuery, myPerson)

#To confirm the table was created successfully
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

#Commit and close connection
myConnection.commit()
myConnection.close()
# Out:
# Streaming output truncated to the last 5000 lines.
#   'greenephilip@martinez-bauer.org',
#   '292 Brooks Inlet',
#   'South Jenniferville',
#   'Georgia',
#   'Tajikistan',
#   '583.727.2179',
#   'Get inside like media. Who east also yes.\n'
#   'Research claim drug serious. Great reach us old. Remember morning feel '
#   'any.\n'
#   'Politics serve bag show a answer class.',
#   '1981-12-05',
#   1160,
#   '2021-02-11 19:35:01.657011',
#   '2021-02-11 19:35:01.657012',
#   '108.208.121.210'),
#  (685,
#   'Bailey Baker DDS',
#   'anthony90@hotmail.com',
#   '45159 Emily Hill Apt. 068',
#   'Curtisfurt',
#   'Colorado',
#   'Albania',
#   '935.938.6368x78109',
#   'Road message political daughter memory stuff already. Billion but others TV '
#   'if whom camera.\n'
#   'Gas in tonight push look water their. Standard per history vote available.',
#   '2000-06-12',
#   1480,
#   '2021-02-11 19:35:01.657752',
#   '2021-02-11 19:35:01.657753',
#   '154.145.79.87'),
#  (686,
#   'Jenna Evans',
#   'friley@cook.net',
#   '9364 Burns Dam Suite 651',
#   'Pattyberg',
#   'Kentucky',
#   'United States Virgin Islands',
#   '(781)359-7145',
#   'Draw factor south star industry account long never. Medical save positive '
#   'matter blood back.\n'
#   'Large decide significant interest. Indeed court red discover. Create use '
#   'think member who.',
#   '2007-04-28',
#   1726,
#   '2021-02-11 19:35:01.658605',
#   '2021-02-11 19:35:01.658606',
#   '170.165.70.125'),
#  (687,
#   'Randy Herman',
#   'gmcdowell@gmail.com',
#   '1479 Patton Circles',
#   'West Jenniferchester',
#   'Illinois',
#   'China',
#   '2774329132',
#   'Skin father suffer position. Seem there stop trade by. Hand science detail '
#   'step entire miss Republican simply.',
#   '1929-09-23',
#   1736,
#   '2021-02-11 19:35:01.659305',
#   '2021-02-11 19:35:01.659306',
#   '22.237.123.47'),
#  (688,
#   'Toni Lawson',
#   'edgarnavarro@lambert-mercado.biz',
#   '29727 Simpson Manor Apt. 194',
#   'Lake Oliviaburgh',
#   'Minnesota',
#   'Hong Kong',
#   '(921)882-1640',
#   'Garden indicate hospital often. Child sense never attack idea parent. '
#   'Natural risk write many. Government serve not yet would economy.',
#   '2000-11-26',
#   1872,
#   '2021-02-11 19:35:01.660281',
#   '2021-02-11 19:35:01.660282',
#   '163.138.204.136'),
#  (689,
#   'Laura Rodgers',
#   'cperez@gmail.com',
#   '0634 Jermaine Row',
#   'Jonathanland',
#   'Florida',
#   'Montenegro',
#   '074.811.1997x354',
#   'Something raise dog give. Help entire or small how bar. Want turn whether '
#   'represent letter. Road actually past require both.',
#   '1909-04-21',
#   2494,
#   '2021-02-11 19:35:01.660987',
#   '2021-02-11 19:35:01.660988',
#   '21.21.233.209'),
#  (690,
#   'Adam Hobbs',
#   'pricemark@harding.net',
#   '412 Cheryl Mill Suite 947',
#   'North Meghan',
#   'Michigan',
#   'El Salvador',
#   '(074)779-6289',
#   'Attention maybe well operation. Level recently notice fly. Program step '
#   'weight few behavior.\n'
#   'Stop worry me. Opportunity tough west give business.',
#   '1908-11-17',
#   1146,
#   '2021-02-11 19:35:01.661998',
#   '2021-02-11 19:35:01.661999',
#   '67.232.43.132'),
#  (691,
#   'Linda Villarreal PhD',
#   'lhernandez@curry-gardner.org',
#   '27459 Greer Drive Apt. 078',
#   'Parkport',
#   'Montana',
#   'Maldives',
#   '(435)186-3619',
#   'A stock throw laugh. Kid change gas order important. Box type tree soon '
#   'true eat.\n'
#   'Building economic direction. Door parent wrong chair age election member.',
#   '1971-06-06',
#   1594,
#   '2021-02-11 19:35:01.662963',
#   '2021-02-11 19:35:01.662964',
#   '195.52.13.173'),
#  (692,
#   'Troy Adkins',
#   'scottrobinson@hernandez-randolph.com',
#   '3785 Rogers Drives',
#   'Port Loriland',
#   'Texas',
#   'Saint Vincent and the Grenadines',
#   '925-756-5150x311',
#   'Democratic class bring century guy. Thing require institution so not.\n'
#   'Support seek season expect let food police. Former across education '
#   'foreign. City cell at issue.',
#   '1996-06-22',
#   1165,
#   '2021-02-11 19:35:01.663961',
#   '2021-02-11 19:35:01.663962',
#   '148.183.211.152'),
#  (693,
#   'Tina Perez',
#   'xfoster@long-figueroa.net',
#   '75226 Jones Place',
#   'Hutchinsonmouth',
#   'Alabama',
#   'Mayotte',
#   '6215360789',
#   'Fight blood feeling. Often tough believe wish just. Owner knowledge also '
#   'professor. Company picture view.\n'
#   'Speak situation success face.',
#   '1965-03-23',
#   1009,
#   '2021-02-11 19:35:01.664903',
#   '2021-02-11 19:35:01.664904',
#   '110.108.198.115'),
#  (694,
#   'Charles Clark',
#   'plopez@gmail.com',
#   '313 Little Mews Suite 527',
#   'North Justin',
#   'New Hampshire',
#   'Tanzania',
#   '(903)699-3631',
#   'Significant threat administration. Order approach process believe. Large '
#   'recent that finally environmental suggest.',
#   '2017-07-18',
#   2473,
#   '2021-02-11 19:35:01.665626',
#   '2021-02-11 19:35:01.665627',
#   '93.108.43.16'),
#  (695,
#   'Ronald Garcia',
#   'michellewyatt@lynch-taylor.com',
#   '326 Lee Points',
#   'Moraleshaven',
#   'North Dakota',
#   'Yemen',
#   '148.728.7638',
#   'House follow people six across door black. Issue truth almost poor task. '
#   'Someone save enjoy body.',
#   '1993-01-01',
#   1818,
#   '2021-02-11 19:35:01.666594',
#   '2021-02-11 19:35:01.666595',
#   '193.165.90.54'),
#  (696,
#   'Kathryn Mcintyre',
#   'manuelsmith@yahoo.com',
#   '56458 Elizabeth Vista',
#   'Port Morgan',
#   'Utah',
#   'Italy',
#   '001-940-256-4156x3419',
#   'Feeling girl employee act. Lot health condition into keep. Environment '
#   'record memory certainly.\n'
#   'Maintain time interview over resource. Listen accept increase.',
#   '1913-02-10',
#   1562,
#   '2021-02-11 19:35:01.667340',
#   '2021-02-11 19:35:01.667341',
#   '217.83.234.16'),
#  (697,
#   'David Leach',
#   'reginaldjackson@yahoo.com',
#   '2510 Bradley Spurs',
#   'Masseyton',
#   'West Virginia',
#   'Panama',
#   '(415)710-7699x306',
#   'Position sound fund southern. Manage production require carry. Age find '
#   'professional.\n'
#   'Believe offer long market. Child final chance nothing.',
#   '2009-02-12',
#   2241,
#   '2021-02-11 19:35:01.668173',
#   '2021-02-11 19:35:01.668174',
#   '133.142.232.62'),
#  (698,
#   'Christine Kennedy',
#   'wspencer@lozano-taylor.com',
#   '41100 Gonzalez Forks',
#   'South Andrewport',
#   'Delaware',
#   'Kazakhstan',
#   '2425929484',
#   'Wall Republican another say majority between.\n'
#   'Truth total activity grow. Player whole voice wall body approach cut. '
#   'During free local of paper.\n'
#   'Tend amount care.',
#   '1918-10-17',
#   1900,
#   '2021-02-11 19:35:01.669122',
#   '2021-02-11 19:35:01.669123',
#   '6.30.160.189'),
#  (699,
#   'Timothy Adams',
#   'bettyjohnson@yahoo.com',
#   '16911 Laura Extension',
#   'Lake Peterside',
#   'Washington',
#   'Liechtenstein',
#   '542-098-3959x97540',
#   'Teacher experience attention decide worker bill dog. Than difference '
#   'during.\n'
#   'Think too not behind win. Loss officer age step. Something news home he '
#   'likely do special.',
#   '2005-07-29',
#   1927,
#   '2021-02-11 19:35:01.669942',
#   '2021-02-11 19:35:01.669943',
#   '172.153.10.36'),
#  (700,
#   'Jennifer Spence',
#   'briannanelson@rivera.com',
#   '6500 Martinez Mountain Apt. 491',
#   'Greenehaven',
#   'North Carolina',
#   'Kuwait',
#   '0657472760',
#   'Budget start lay cost build. Air more month join life movement keep. '
#   'Customer game smile lot thus everything forward.',
#   '2000-07-30',
#   1082,
#   '2021-02-11 19:35:01.670884',
#   '2021-02-11 19:35:01.670885',
#   '138.183.36.171'),
#  (701,
#   'Rebecca Rose',
#   'meghan22@yahoo.com',
#   '90442 Allen Extensions',
#   'Dustinchester',
#   'Iowa',
#   'Saudi Arabia',
#   '986-798-7945x5811',
#   'Seat go about coach note take wide. Central become natural course concern '
#   'college.\n'
#   'House peace resource. Media inside film billion save style. Total imagine '
#   'build exist organization thing.',
#   '2002-01-11',
#   2246,
#   '2021-02-11 19:35:01.671622',
#   '2021-02-11 19:35:01.671623',
#   '113.175.119.85'),
#  (702,
#   'Travis Jackson',
#   'amcpherson@jackson.com',
#   '173 Kennedy River',
#   'Pamelashire',
#   'Minnesota',
#   'Trinidad and Tobago',
#   '+1-995-220-6700x329',
#   'Wonder nothing least per. Again well the nation between small idea. Brother '
#   'hear soldier arm seek ability certain there. Face cut national middle share '
#   'five project.',
#   '1959-09-28',
#   1079,
#   '2021-02-11 19:35:01.672439',
#   '2021-02-11 19:35:01.672440',
#   '65.25.114.231'),
#  (703,
#   'Mr. Christopher Thompson',
#   'john89@decker.com',
#   '8751 Williams Forest Suite 456',
#   'Tateshire',
#   'Illinois',
#   'Mozambique',
#   '716.021.9130',
#   'Actually ten reveal down. Guy southern involve local quality.\n'
#   'Conference place training adult old economy including. Appear tax start '
#   'great push.',
#   '1964-03-03',
#   1728,
#   '2021-02-11 19:35:01.673454',
#   '2021-02-11 19:35:01.673456',
#   '30.93.142.187'),
#  (704,
#   'Daniel Morris',
#   'gary70@hood.com',
#   '83363 Lyons Trace',
#   'New Lauramouth',
#   'Alaska',
#   'Egypt',
#   '001-448-377-0991x0768',
#   'Usually story reduce to save. Movement according church get. Chance pass '
#   'break street music often investment line. World focus only step but '
#   'situation.',
#   '1991-05-04',
#   2169,
#   '2021-02-11 19:35:01.674278',
#   '2021-02-11 19:35:01.674279',
#   '17.227.56.225'),
#  (705,
#   'Jessica Murphy',
#   'carrlouis@yahoo.com',
#   '7257 Lopez Ridges',
#   'Port Mariaport',
#   'Pennsylvania',
#   'Madagascar',
#   '216-335-5624',
#   'Indeed table glass. Little enough born find.',
#   '1999-04-08',
#   1775,
#   '2021-02-11 19:35:01.675060',
#   '2021-02-11 19:35:01.675061',
#   '80.193.224.103'),
#  (706,
#   'Kurt Sloan',
#   'dhenry@medina.com',
#   '893 Caitlin Lakes Suite 381',
#   'Williamview',
#   'Washington',
#   'Philippines',
#   '+1-607-020-0009x049',
#   'Many management either admit still raise blue. Do fill test likely computer '
#   'pick. College so little arm always minute.',
#   '1951-10-24',
#   1498,
#   '2021-02-11 19:35:01.675856',
#   '2021-02-11 19:35:01.675857',
#   '73.207.146.169'),
#  (707,
#   'Mrs. Jill Logan',
#   'lisadennis@hotmail.com',
#   '83376 Mcdaniel Viaduct',
#   'East Paulburgh',
#   'Utah',
#   'Gabon',
#   '2214485873',
#   'Avoid exactly together likely on sound just. However hot travel energy '
#   'these develop subject. From the third who.',
#   '2014-02-26',
#   1799,
#   '2021-02-11 19:35:01.676638',
#   '2021-02-11 19:35:01.676639',
#   '44.93.99.43'),
#  (708,
#   'Gregory Bates',
#   'jacobcollins@yahoo.com',
#   '80787 Charlotte Brooks',
#   'Madelinemouth',
#   'Arizona',
#   'British Virgin Islands',
#   '(195)851-7017',
#   'Whatever today others. Ready design by every rate really whose.\n'
#   'Culture thus blue bar century training policy. Price star low better ground '
#   'another. Respond look accept sure.',
#   '1980-07-30',
#   1495,
#   '2021-02-11 19:35:01.677366',
#   '2021-02-11 19:35:01.677367',
#   '121.173.136.109'),
#  (709,
#   'Rebecca Brown',
#   'laurenramirez@hotmail.com',
#   '162 George Corners',
#   'Robertmouth',
#   'Georgia',
#   'Papua New Guinea',
#   '658.206.2136x0091',
#   'Spring bit research fly likely partner hit positive. Happy majority '
#   'pressure deal food gun race. Use politics as way action say.',
#   '1905-11-13',
#   2182,
#   '2021-02-11 19:35:01.678137',
#   '2021-02-11 19:35:01.678139',
#   '112.4.95.115'),
#  (710,
#   'Lori Gaines',
#   'pamela62@crawford.biz',
#   '798 Whitney Port Apt. 421',
#   'East Jonathan',
#   'Florida',
#   'Chile',
#   '500-859-1644x6127',
#   'Add morning bad hand. Knowledge town red. Deep painting election relate '
#   'population stop together.\n'
#   'Cold toward large close lose center suggest. Ability model military dark '
#   'beat.',
#   '1958-02-20',
#   2288,
#   '2021-02-11 19:35:01.678938',
#   '2021-02-11 19:35:01.678940',
#   '210.44.127.69'),
#  (711,
#   'Derrick Pearson',
#   'hcobb@copeland.com',
#   '8882 Curtis Ranch Apt. 267',
#   'East Davidville',
#   'Illinois',
#   'Belize',
#   '+1-762-531-1332x1861',
#   'Quality management song protect street. Service scene shoulder offer '
#   'certainly. Different price child agency.\n'
#   'Religious when impact soon professional trade. Fact tell write be.',
#   '1909-01-08',
#   2131,
#   '2021-02-11 19:35:01.680443',
#   '2021-02-11 19:35:01.680444',
#   '70.95.176.116'),
#  (712,
#   'Austin Ayala',
#   'danaroach@gmail.com',
#   '016 Bray Shoals Suite 337',
#   'Vincentburgh',
#   'Virginia',
#   'Paraguay',
#   '459-638-9670x8325',
#   'Prepare country amount without president local. Event account national '
#   'glass. Business appear change word anything improve.',
#   '1911-05-27',
#   1325,
#   '2021-02-11 19:35:01.682346',
#   '2021-02-11 19:35:01.682348',
#   '162.141.217.246'),
#  (713,
#   'Michael Herman',
#   'hardinjoseph@griffin.info',
#   '1633 Richardson Inlet',
#   'Buchananmouth',
#   'Nebraska',
#   'Jordan',
#   '6373727008',
#   'Final morning area draw article number within. Herself join cultural. Their '
#   'man information approach.',
#   '1941-12-27',
#   1408,
#   '2021-02-11 19:35:01.683390',
#   '2021-02-11 19:35:01.683391',
#   '16.39.4.187'),
#  (714,
#   'Dr. Brandon Hammond MD',
#   'shepardrebecca@gmail.com',
#   '77349 Tran Fall Apt. 020',
#   'Spencermouth',
#   'Maine',
#   'Malta',
#   '900-651-3985x226',
#   'Down while sure direction area professor. Imagine about movement show. '
#   'Future coach oil water.\n'
#   'Such response fill everything civil office seem. Admit friend whether sit '
#   'factor ago yes.',
#   '1996-01-02',
#   2085,
#   '2021-02-11 19:35:01.685085',
#   '2021-02-11 19:35:01.685086',
#   '196.62.184.235'),
#  (715,
#   'Tyler Parsons',
#   'dennisrobin@hotmail.com',
#   '228 Andrea Creek Suite 950',
#   'Lake Stephen',
#   'Hawaii',
#   'Burundi',
#   '+1-915-630-6991x39257',
#   'Identify safe east year floor. Art room myself view explain government '
#   'truth.\n'
#   'Surface huge maintain education item common. General enjoy pick however '
#   'model fact. Reason president life.',
#   '1920-07-06',
#   1600,
#   '2021-02-11 19:35:01.686052',
#   '2021-02-11 19:35:01.686053',
#   '154.107.137.121'),
#  (716,
#   'Justin Cabrera',
#   'stephensnow@newton.org',
#   '0210 Johnson Gateway',
#   'Tanyaburgh',
#   'New Hampshire',
#   'Chile',
#   '527.606.5375',
#   'Medical check white social force media.\n'
#   'Trial season business property community resource across. Develop assume '
#   'every several training agency.',
#   '1924-07-08',
#   1380,
#   '2021-02-11 19:35:01.687213',
#   '2021-02-11 19:35:01.687215',
#   '27.15.110.146'),
#  (717,
#   'Anthony Carey',
#   'michaelhowell@gomez.net',
#   '6811 Richard Burg',
#   'Port Karenchester',
#   'New York',
#   'Brunei Darussalam',
#   '018.841.2077x35442',
#   'Probably hot ability week surface admit defense. Radio Mr society reach '
#   'high. Raise whole whole community.\n'
#   'Fly activity local fight alone will any improve. Night soon sing nearly.',
#   '1991-06-21',
#   1811,
#   '2021-02-11 19:35:01.688183',
#   '2021-02-11 19:35:01.688184',
#   '6.126.30.107'),
#  (718,
#   'David Wood',
#   'theresa36@gmail.com',
#   '333 Roger Forks Apt. 969',
#   'Albertfort',
#   'Kansas',
#   'Hong Kong',
#   '481.352.9032x77084',
#   'Decide wish whom him month animal.\n'
#   'Wear fly reality conference allow. Carry wall safe. They single nation '
#   'stop.',
#   '2016-09-21',
#   1920,
#   '2021-02-11 19:35:01.689630',
#   '2021-02-11 19:35:01.689632',
#   '10.145.254.236'),
#  (719,
#   'John Moore',
#   'chughes@baker.info',
#   '619 Gerald Haven Suite 667',
#   'Kirkport',
#   'Oregon',
#   'Monaco',
#   '480.197.2353x58999',
#   'Key wind before one start during must public. Home generation road rate.\n'
#   'Role report describe crime right citizen material. Approach they carry '
#   'everything. Special from shake apply now third.',
#   '2012-10-24',
#   2190,
#   '2021-02-11 19:35:01.690646',
#   '2021-02-11 19:35:01.690647',
#   '44.16.150.46'),
#  (720,
#   'Don Kelley',
#   'karenramirez@hotmail.com',
#   '881 Hickman Wall Apt. 343',
#   'South Phillipstad',
#   'Maine',
#   'Grenada',
#   '(519)100-3572',
#   'Glass likely about skill. Know already light which. Condition trial cold '
#   'through foreign performance market.\n'
#   'Past behind month want apply.',
#   '1945-03-28',
#   2034,
#   '2021-02-11 19:35:01.691497',
#   '2021-02-11 19:35:01.691500',
#   '177.210.235.101'),
#  (721,
#   'Chelsea Li',
#   'michelle83@gaines.net',
#   '2626 Henderson Orchard',
#   'South Christina',
#   'New Mexico',
#   'Tunisia',
#   '(244)908-8477x802',
#   'Free spring lose TV region theory. Number around somebody past hospital '
#   'individual. Little participant almost state wait table many.',
#   '1989-12-15',
#   1791,
#   '2021-02-11 19:35:01.692681',
#   '2021-02-11 19:35:01.692682',
#   '160.48.33.144'),
#  (722,
#   'Tiffany Elliott',
#   'nhowe@yahoo.com',
#   '6835 Kim Cape Apt. 436',
#   'Andrewborough',
#   'North Dakota',
#   'Saint Kitts and Nevis',
#   '014-400-7561',
#   'Positive modern avoid read together develop case fill. Song property '
#   'support western age tonight. Prove force minute both.\n'
#   'Program close possible east goal who.',
#   '1908-01-22',
#   1524,
#   '2021-02-11 19:35:01.693792',
#   '2021-02-11 19:35:01.693793',
#   '33.202.77.143'),
#  (723,
#   'Carolyn Walker',
#   'gregoryjackson@hotmail.com',
#   '376 Samantha Manor',
#   'North Catherinechester',
#   'Hawaii',
#   'Cocos (Keeling) Islands',
#   '160-306-1407',
#   'View brother information summer upon figure address. Surface great behind '
#   'nearly.\n'
#   'Foot yourself study style value. Away program describe.',
#   '1991-11-08',
#   1617,
#   '2021-02-11 19:35:01.694913',
#   '2021-02-11 19:35:01.694914',
#   '207.61.70.138'),
#  (724,
#   'Stephanie Stevens',
#   'awheeler@hansen.com',
#   '35903 Richardson Roads',
#   'Tinaburgh',
#   'Nebraska',
#   'Albania',
#   '846.628.7257x962',
#   'Speak yourself herself her first song yourself. Investment along create '
#   'conference appear city party. Dog growth degree.',
#   '1996-04-06',
#   1371,
#   '2021-02-11 19:35:01.695786',
#   '2021-02-11 19:35:01.695787',
#   '50.114.188.192'),
#  (725,
#   'Bryan Weber',
#   'davidhall@hotmail.com',
#   '85440 Trevor Prairie',
#   'Port Christopherburgh',
#   'Oregon',
#   'Guam',
#   '001-387-740-7463x861',
#   'Career within paper better. Evidence its really area town. Century travel '
#   'account couple. Carry high somebody each here none east.\n'
#   'Doctor second around particularly hand.',
#   '1919-04-14',
#   2175,
#   '2021-02-11 19:35:01.697120',
#   '2021-02-11 19:35:01.697121',
#   '164.39.49.144'),
#  (726,
#   'Kevin Rose',
#   'mtorres@shepard-walton.com',
#   '5575 Waller Cove',
#   'Krystalmouth',
#   'Minnesota',
#   'Ireland',
#   '(270)236-4957',
#   'He kitchen in young interesting writer perhaps cold. Foreign politics on '
#   'throughout consumer nation writer. Seek spring raise.\n'
#   'Cover happen anything. Beat mean them possible major back.',
#   '1944-04-23',
#   1376,
#   '2021-02-11 19:35:01.699047',
#   '2021-02-11 19:35:01.699048',
#   '29.41.118.181'),
#  (727,
#   'Lisa Walker',
#   'kerry15@taylor.com',
#   '39392 Warner Green',
#   'Port Jeffreyfort',
#   'Iowa',
#   'Turkey',
#   '755-142-5717x788',
#   'Movement above show tend financial. Also green which although. Rich eye '
#   'keep major.\n'
#   'Real hit large would national. Yet discover fact improve admit.',
#   '1938-10-27',
#   1210,
#   '2021-02-11 19:35:01.700077',
#   '2021-02-11 19:35:01.700078',
#   '32.111.92.228'),
#  (728,
#   'Erica Conway',
#   'walkerjacob@espinoza.net',
#   '5765 Ward Road',
#   'South Katherine',
#   'North Dakota',
#   'Yemen',
#   '621.855.1307',
#   'International field as first theory natural blue. Benefit road dark budget '
#   'particularly maintain. Small itself structure role federal.',
#   '2011-10-09',
#   1696,
#   '2021-02-11 19:35:01.701178',
#   '2021-02-11 19:35:01.701179',
#   '102.233.21.222'),
#  (729,
#   'Rebecca Stewart',
#   'grogers@boyd.com',
#   '5470 John Port Apt. 194',
#   'Riveramouth',
#   'South Carolina',
#   'Lithuania',
#   '(412)141-1138x226',
#   'Just pull answer success water. Exactly plan daughter stand finally seat '
#   'authority sell. Movement night we your process somebody draw.',
#   '1992-06-21',
#   2075,
#   '2021-02-11 19:35:01.703150',
#   '2021-02-11 19:35:01.703151',
#   '144.8.162.253'),
#  (730,
#   'Andrew Scott',
#   'doncolon@meza-hansen.com',
#   '053 Ross Row',
#   'Wallview',
#   'California',
#   'Kiribati',
#   '+1-785-112-5448x29765',
#   'Population choice learn compare. Back medical as enter simply.',
#   '2004-02-16',
#   1347,
#   '2021-02-11 19:35:01.704856',
#   '2021-02-11 19:35:01.704859',
#   '100.203.234.170'),
#  (731,
#   'Sandra Blankenship',
#   'scottgilbert@hotmail.com',
#   '41146 John Estates',
#   'Lake Danielchester',
#   'Massachusetts',
#   'Oman',
#   '+1-930-767-3032',
#   'Series provide common offer behavior response herself. Station spring other '
#   'military strong whatever choose. Husband town scientist store by stock.',
#   '1976-01-24',
#   1303,
#   '2021-02-11 19:35:01.705773',
#   '2021-02-11 19:35:01.705774',
#   '10.99.207.138'),
#  (732,
#   'Mr. Jeremiah Smith Jr.',
#   'james26@yahoo.com',
#   '492 Hampton Brook Suite 985',
#   'Villanuevaberg',
#   'Pennsylvania',
#   'Nepal',
#   '866-037-1254x793',
#   'Range religious half as their consider east. Reduce stay economic happen '
#   'tree decade.\n'
#   'Others drive social line outside test. Career well performance want.',
#   '1976-05-04',
#   1755,
#   '2021-02-11 19:35:01.706617',
#   '2021-02-11 19:35:01.706619',
#   '199.203.1.77'),
#  (733,
#   'Patrick Schwartz',
#   'reeveserica@hotmail.com',
#   '9338 Powell Overpass',
#   'North Michellechester',
#   'Oklahoma',
#   'Suriname',
#   '174-811-1119',
#   'Understand economic from economic determine. Party build majority feeling '
#   'experience officer. Water organization media economic cultural magazine '
#   'nothing.',
#   '1907-08-10',
#   1819,
#   '2021-02-11 19:35:01.707384',
#   '2021-02-11 19:35:01.707385',
#   '40.49.161.223'),
#  (734,
#   'Christopher Williams',
#   'robertmartinez@flores-rodriguez.com',
#   '7972 Christina Orchard Apt. 521',
#   'Hullmouth',
#   'West Virginia',
#   'Niger',
#   '001-126-208-2333',
#   'Himself pattern important blood.\n'
#   'President certainly build. Government could skill trip across sign above. '
#   'Before lay whether indicate push remain.\n'
#   'Report thing up study him south boy.',
#   '1938-10-03',
#   1086,
#   '2021-02-11 19:35:01.708736',
#   '2021-02-11 19:35:01.708738',
#   '129.5.9.7'),
#  (735,
#   'Scott Walton',
#   'hooversamantha@green-alvarado.biz',
#   '21255 Kenneth Gardens',
#   'Port Michelle',
#   'Massachusetts',
#   'Chad',
#   '001-809-081-8897x6854',
#   'Finish order international arrive candidate. Race American after teach '
#   'without. Adult fill manage too one.\n'
#   'Expect huge them movement arm painting mouth. Sort item assume nice.',
#   '1987-05-27',
#   2186,
#   '2021-02-11 19:35:01.709826',
#   '2021-02-11 19:35:01.709827',
#   '114.59.44.15'),
#  (736,
#   'Brenda Kelley',
#   'jonesanthony@gmail.com',
#   '20473 Smith Greens Apt. 595',
#   'Jonestown',
#   'Hawaii',
#   'Falkland Islands (Malvinas)',
#   '148.204.2977',
#   'Approach opportunity reflect television. Chair likely before possible '
#   'career. Western body citizen network.',
#   '1923-12-05',
#   1492,
#   '2021-02-11 19:35:01.710712',
#   '2021-02-11 19:35:01.710713',
#   '184.143.99.34'),
#  (737,
#   'Erica Gay',
#   'qpotter@johnson-johnson.com',
#   '685 Michael Parkway Suite 491',
#   'East Christinashire',
#   'Wyoming',
#   'Venezuela',
#   '001-088-248-1981',
#   'Commercial by couple thus least concern. Someone every modern gas rate.\n'
#   'Show hotel check require else customer. Including foreign order opportunity '
#   'occur budget collection.',
#   '1911-01-24',
#   2285,
#   '2021-02-11 19:35:01.711685',
#   '2021-02-11 19:35:01.711687',
#   '55.152.232.164'),
#  (738,
#   'Alicia Robinson',
#   'ewyatt@hotmail.com',
#   '430 Christopher Keys',
#   'New Rhonda',
#   'Wyoming',
#   'Kuwait',
#   '+1-726-010-0739x97988',
#   'Pull himself detail threat. Start room truth building speech up.\n'
#   'Prove billion green Congress over city majority resource. Boy east under '
#   'good anyone wind art.',
#   '1905-08-01',
#   1208,
#   '2021-02-11 19:35:01.712409',
#   '2021-02-11 19:35:01.712410',
#   '15.201.222.245'),
#  (739,
#   'Yvette Davis',
#   'scottbrown@hotmail.com',
#   '92031 Adam Stream',
#   'Stephanieside',
#   'Wisconsin',
#   'Kazakhstan',
#   '913.087.2052x101',
#   'More others serve yet look meeting. Lose carry attack his case standard. '
#   'Group but minute your who.\n'
#   'Movement take growth. Order spring strategy begin.',
#   '1950-03-27',
#   2139,
#   '2021-02-11 19:35:01.713196',
#   '2021-02-11 19:35:01.713197',
#   '60.100.85.24'),
#  (740,
#   'Edward Roy',
#   'huffmanvictoria@gonzalez.com',
#   '9895 Wells Lane Apt. 913',
#   'West Adam',
#   'Arizona',
#   'Tonga',
#   '145.184.5663x3106',
#   'Miss education change process truth. Make trouble night crime worker. '
#   'Source make total audience.\n'
#   'Beat couple through morning size. Shake deal cover last. National '
#   'themselves would reach cost cause.',
#   '1908-04-05',
#   2439,
#   '2021-02-11 19:35:01.714176',
#   '2021-02-11 19:35:01.714178',
#   '113.188.55.142'),
#  (741,
#   'Christopher Mitchell MD',
#   'kelsey97@rollins-schmidt.net',
#   '91190 Alexis Tunnel',
#   'West Jesushaven',
#   'Tennessee',
#   'Vanuatu',
#   '439.602.1864',
#   'Ability performance church mother hope million option. Own scientist low '
#   'somebody. Party indeed box final.\n'
#   'Such wind high small. Position skin into.',
#   '1961-08-22',
#   1630,
#   '2021-02-11 19:35:01.715339',
#   '2021-02-11 19:35:01.715342',
#   '166.252.106.232'),
#  (742,
#   'Sara Carr',
#   'tanya41@hotmail.com',
#   '2585 Dougherty Plain',
#   'Port Kristenhaven',
#   'Iowa',
#   'Indonesia',
#   '060-766-1661',
#   'Author two pay watch continue identify agency magazine.\n'
#   'Usually party father. Radio TV Mrs expect husband.\n'
#   'Though face Mrs need down movie population heart. Would audience success.',
#   '1952-10-21',
#   2478,
#   '2021-02-11 19:35:01.716275',
#   '2021-02-11 19:35:01.716276',
#   '36.188.236.19'),
#  (743,
#   'Daniel Campbell',
#   'kristin99@bright.org',
#   '4802 Kim View',
#   'New Theresachester',
#   'Indiana',
#   'Turkey',
#   '001-983-497-5853x3566',
#   'Wait friend history possible training. Enter game stand also. Among power '
#   'light door. Since time include partner store someone sure.\n'
#   'Like east writer under very responsibility group.',
#   '1941-09-27',
#   1119,
#   '2021-02-11 19:35:01.717533',
#   '2021-02-11 19:35:01.717535',
#   '41.79.197.91'),
#  (744,
#   'Jill Robinson',
#   'lopeztara@hotmail.com',
#   '400 Whitney Plaza Suite 119',
#   'Markview',
#   'Minnesota',
#   'Russian Federation',
#   '+1-962-983-6583x099',
#   'Local cell center skill. Major fast national put risk hot then.\n'
#   'Second wrong travel. A since chair work lead war space.',
#   '1916-08-02',
#   1685,
#   '2021-02-11 19:35:01.718641',
#   '2021-02-11 19:35:01.718642',
#   '154.226.120.227'),
#  (745,
#   'Ricky Moore',
#   'andrea11@todd.info',
#   '12103 Juan Orchard Apt. 892',
#   'Maloneburgh',
#   'Georgia',
#   'Russian Federation',
#   '+1-357-400-9591x2641',
#   'And despite lay development drive student each reality. Maybe nearly hair.',
#   '1980-09-16',
#   1798,
#   '2021-02-11 19:35:01.719512',
#   '2021-02-11 19:35:01.719513',
#   '32.214.240.26'),
#  (746,
#   'Cathy Harper',
#   'pattersonsandra@hotmail.com',
#   '6149 Manuel Glen',
#   'South Katrina',
#   'Utah',
#   'Afghanistan',
#   '179.106.5711',
#   'Career market who although bit station memory. Fill through relationship '
#   'increase. Television bank teach protect live despite provide.',
#   '1922-11-14',
#   1621,
#   '2021-02-11 19:35:01.720290',
#   '2021-02-11 19:35:01.720291',
#   '66.15.184.253'),
#  (747,
#   'Kelly Jordan',
#   'wwong@wolf.com',
#   '265 Michele Unions',
#   'Randychester',
#   'Massachusetts',
#   'Peru',
#   '662.045.9501',
#   'Company product financial. Direction really expect candidate later key '
#   'control. Debate professor prove civil away.',
#   '2002-02-03',
#   2251,
#   '2021-02-11 19:35:01.722656',
#   '2021-02-11 19:35:01.722659',
#   '113.96.208.99'),
#  (748,
#   'Heather Mendez',
#   'phelpsjo@yahoo.com',
#   '69539 Aaron Valley',
#   'North Tiffany',
#   'West Virginia',
#   'Iraq',
#   '171-469-3432x29738',
#   'Help glass film second lose. Of near option according game. Represent '
#   'mother go.\n'
#   'Exactly audience purpose.',
#   '2002-11-12',
#   1560,
#   '2021-02-11 19:35:01.724025',
#   '2021-02-11 19:35:01.724026',
#   '124.89.80.192'),
#  (749,
#   'Jason Adams',
#   'justin49@santiago-matthews.info',
#   '47831 Williamson Walks Apt. 806',
#   'Lake Deanna',
#   'Nebraska',
#   'Slovenia',
#   '241.902.7430',
#   'Focus right what nor name. Future manage everyone free down agree.\n'
#   'Bad also order reach suddenly over. Happen image himself letter.\n'
#   'Network energy future. You everyone each test happy.',
#   '1907-04-21',
#   2044,
#   '2021-02-11 19:35:01.725051',
#   '2021-02-11 19:35:01.725053',
#   '62.120.113.104'),
#  (750,
#   'Ashley Higgins',
#   'youngandrew@gmail.com',
#   '88142 Watkins Camp Suite 023',
#   'Stevenshire',
#   'Wyoming',
#   'Netherlands',
#   '001-995-062-9378x30468',
#   'Identify rule require writer fight right dinner area. Probably nice main '
#   'free reality always. Seven candidate left nothing.',
#   '1953-10-10',
#   2044,
#   '2021-02-11 19:35:01.726343',
#   '2021-02-11 19:35:01.726345',
#   '124.242.46.127'),
#  (751,
#   'Dana Hayes',
#   'sanchezcrystal@yahoo.com',
#   '05661 Ian Mission Apt. 024',
#   'Smithburgh',
#   'California',
#   'Sudan',
#   '856-656-0647',
#   'Agreement whole majority hour movement only great. Explain available big '
#   'record.\n'
#   'Place special modern upon. Community newspaper community data family.',
#   '1992-12-12',
#   2155,
#   '2021-02-11 19:35:01.728365',
#   '2021-02-11 19:35:01.728367',
#   '54.46.147.158'),
#  (752,
#   'Luke Chan',
#   'changkathleen@yahoo.com',
#   '122 Amanda Loop',
#   'Lake Brentshire',
#   'New Hampshire',
#   'Uganda',
#   '153.174.7507x09206',
#   'Off under theory high development oil doctor. Free everyone between '
#   'something word job.\n'
#   'Religious trouble morning size let right. I bad among group need fine.',
#   '2013-02-27',
#   1475,
#   '2021-02-11 19:35:01.729349',
#   '2021-02-11 19:35:01.729350',
#   '19.135.140.229'),
#  (753,
#   'Denise Jones',
#   'maldonadolaura@yahoo.com',
#   '53205 Emma Square Suite 151',
#   'East Jenna',
#   'Kansas',
#   'Nigeria',
#   '882-453-8812x0892',
#   'Production before former note. Inside around American test.\n'
#   'Southern one year detail miss my. Beat top operation name road. Three rock '
#   'build a father.',
#   '1961-06-23',
#   1178,
#   '2021-02-11 19:35:01.730227',
#   '2021-02-11 19:35:01.730228',
#   '175.208.238.32'),
#  (754,
#   'Charles Terry',
#   'burnsbrendan@nichols.org',
#   '29926 Joshua Orchard Suite 817',
#   'Glennland',
#   'Rhode Island',
#   'Saint Barthelemy',
#   '001-085-256-6132x016',
#   'They offer someone give. Art book student season receive various.\n'
#   'With Mr degree view group. Design view nice.\n'
#   'Answer than provide occur mission clearly heavy.',
#   '1923-03-01',
#   2170,
#   '2021-02-11 19:35:01.731972',
#   '2021-02-11 19:35:01.731973',
#   '116.159.23.58'),
#  (755,
#   'Robert Hernandez',
#   'campbellbrian@gmail.com',
#   '27538 Richard Path',
#   'East Kimberly',
#   'Louisiana',
#   'Cocos (Keeling) Islands',
#   '670.250.0371x3386',
#   'Health real last stock glass. Talk kind soldier bar know decision hair.\n'
#   'Believe behind similar I rich. Feel and wear probably. Magazine both range '
#   'control head.',
#   '1906-06-20',
#   2257,
#   '2021-02-11 19:35:01.733134',
#   '2021-02-11 19:35:01.733136',
#   '155.94.132.24'),
#  (756,
#   'Jeanette Gaines',
#   'anthonybrown@williams.info',
#   '05142 Shields Cove',
#   'New Jorgechester',
#   'Kentucky',
#   'Pitcairn Islands',
#   '001-716-427-4656',
#   'Toward get task else look interview. Opportunity administration happen whom '
#   'alone believe.\n'
#   'Place simple sell reason room daughter.',
#   '1907-02-09',
#   2093,
#   '2021-02-11 19:35:01.734115',
#   '2021-02-11 19:35:01.734117',
#   '71.46.103.35'),
#  (757,
#   'Mr. Joseph Thomas',
#   'bryan53@gmail.com',
#   '74178 Kimberly Glens',
#   'West Jenniferside',
#   'Delaware',
#   'Dominican Republic',
#   '001-279-027-8840x40927',
#   'Green spring respond sometimes consider strategy Mr. Station statement '
#   'soldier. Decade friend office water.',
#   '1976-11-13',
#   2461,
#   '2021-02-11 19:35:01.734843',
#   '2021-02-11 19:35:01.734844',
#   '25.249.31.86'),
#  (758,
#   'Thomas Hurley',
#   'jack00@harrison.com',
#   '5286 Howard Trafficway Suite 953',
#   'North Danielle',
#   'Michigan',
#   'Bosnia and Herzegovina',
#   '981-365-2825x844',
#   'Free hold back yard same beautiful. Lawyer night up. Seven source outside '
#   'because whatever just.',
#   '1963-11-02',
#   1193,
#   '2021-02-11 19:35:01.735692',
#   '2021-02-11 19:35:01.735693',
#   '131.211.93.71'),
#  (759,
#   'Michael Owen',
#   'scottclark@brown.com',
#   '53458 Jeffrey Highway',
#   'North Danielshire',
#   'Pennsylvania',
#   'Niger',
#   '234.133.8905x5945',
#   'Like country popular heavy.\n'
#   'Car present practice law pattern happen. Along option stuff it whether.',
#   '1967-12-07',
#   2269,
#   '2021-02-11 19:35:01.736797',
#   '2021-02-11 19:35:01.736798',
#   '128.41.230.239'),
#  (760,
#   'Brian Hobbs',
#   'ballkevin@gmail.com',
#   '431 Tracey Trail Suite 811',
#   'Hartmanburgh',
#   'Illinois',
#   'Bahamas',
#   '394-205-9864x5265',
#   'Success week entire now beyond. Form wide tell big garden especially.\n'
#   'Task determine two the crime sister. About environment experience man ever '
#   'often gun. Water which event drop tough security.',
#   '1970-04-05',
#   2281,
#   '2021-02-11 19:35:01.737648',
#   '2021-02-11 19:35:01.737649',
#   '19.21.254.111'),
#  (761,
#   'Toni Smith',
#   'cartercharles@yahoo.com',
#   '6345 Bowman Walk',
#   'Lake Brian',
#   'Maryland',
#   'Benin',
#   '+1-863-518-4151',
#   'Only worry per ball. Interesting thank state near tree husband tell.\n'
#   'Dog decide during protect. These toward task five analysis. Board reduce '
#   'fish. Itself activity south senior lot tonight.',
#   '1916-12-01',
#   1037,
#   '2021-02-11 19:35:01.738496',
#   '2021-02-11 19:35:01.738497',
#   '115.97.94.110'),
#  (762,
#   'Donald Simpson',
#   'cynthia04@gmail.com',
#   '548 Kaitlyn Trace',
#   'West Nicolestad',
#   'Arkansas',
#   'Samoa',
#   '+1-359-863-2578x86351',
#   'Issue before player now situation do machine. Environmental several land '
#   'machine knowledge.\n'
#   'Professor message pay his level. Her that station fight base day.',
#   '1925-12-31',
#   2142,
#   '2021-02-11 19:35:01.739180',
#   '2021-02-11 19:35:01.739181',
#   '42.58.249.193'),
#  (763,
#   'Tom Hernandez',
#   'ricky05@patel.com',
#   '151 Brooks Shoals Suite 055',
#   'Ryanview',
#   'Illinois',
#   'Senegal',
#   '113-696-5070',
#   'Chance what character painting song. Sure yet wear.',
#   '1995-08-17',
#   2456,
#   '2021-02-11 19:35:01.740156',
#   '2021-02-11 19:35:01.740157',
#   '180.124.58.75'),
#  (764,
#   'Douglas Little',
#   'melvinwilliams@gmail.com',
#   '72091 Elliott Viaduct Apt. 594',
#   'South Pamela',
#   'Maine',
#   'Costa Rica',
#   '369.936.3712x7211',
#   'Matter chance very pick from. Only arm little statement body time.\n'
#   'Become organization effort cost will forget. Inside site suddenly describe '
#   'particularly. Pick ever cover owner.',
#   '1986-07-10',
#   1922,
#   '2021-02-11 19:35:01.740982',
#   '2021-02-11 19:35:01.740984',
#   '185.68.91.17'),
#  (765,
#   'Spencer Goodwin',
#   'kelseytaylor@hotmail.com',
#   '15147 Mitchell Square',
#   'Masonville',
#   'Vermont',
#   'Kenya',
#   '001-375-154-0209x0930',
#   'Traditional win notice executive. Final push machine their our happen '
#   'election market. Manager situation key.',
#   '1998-04-03',
#   1031,
#   '2021-02-11 19:35:01.741807',
#   '2021-02-11 19:35:01.741808',
#   '38.170.117.63'),
#  (766,
#   'Cathy Olson',
#   'rperez@suarez-robinson.com',
#   '79093 Kyle Lake Apt. 942',
#   'Stevensmouth',
#   'Louisiana',
#   'Bulgaria',
#   '1460257572',
#   'Listen guy national them record point can. Recently message music herself.\n'
#   'Wonder point bring police wear possible. Along not truth. Concern book '
#   'every foreign determine until fish.',
#   '1945-04-23',
#   1920,
#   '2021-02-11 19:35:01.743785',
#   '2021-02-11 19:35:01.743786',
#   '160.85.121.140'),
#  (767,
#   'James Carson',
#   'glopez@martinez.biz',
#   '939 Janice Springs',
#   'Cheyenneport',
#   'Delaware',
#   'Nigeria',
#   '138-504-6097',
#   'Lead good effort report.\n'
#   'Kitchen entire media player you. Always line project. Sound break than '
#   'series amount style.',
#   '2008-09-20',
#   2481,
#   '2021-02-11 19:35:01.745619',
#   '2021-02-11 19:35:01.745620',
#   '204.143.196.251'),
#  (768,
#   'Robert Gilbert',
#   'annbeck@barrett-cole.org',
#   '73839 Albert Pine Suite 717',
#   'Lake Scottchester',
#   'Oregon',
#   'Bhutan',
#   '108.575.3223x388',
#   'All yard turn green. Over apply edge every almost. Kind reflect compare. '
#   'Wear bank item model.\n'
#   'Remain benefit race concern many site. Family involve truth fear.',
#   '1974-11-13',
#   2037,
#   '2021-02-11 19:35:01.746717',
#   '2021-02-11 19:35:01.746719',
#   '217.116.37.115'),
#  (769,
#   'Jodi Campbell',
#   'angela08@hall.com',
#   '69144 Vaughn Greens Suite 279',
#   'Port Lindsay',
#   'Maine',
#   'Ethiopia',
#   '(431)576-3231',
#   'Air week field mouth. Recently yourself lead return.',
#   '1978-04-21',
#   2302,
#   '2021-02-11 19:35:01.747576',
#   '2021-02-11 19:35:01.747577',
#   '152.166.199.214'),
#  (770,
#   'Michael Ramirez',
#   'joshuagilbert@yahoo.com',
#   '80735 Ray Underpass Suite 243',
#   'Jenniferstad',
#   'Kentucky',
#   'American Samoa',
#   '(272)380-5378x314',
#   'Few someone right second. Above somebody type effort issue up. Lot foot '
#   'country study amount address fine.\n'
#   'Tax his series treat example. Care can remain class.',
#   '1937-07-31',
#   1658,
#   '2021-02-11 19:35:01.748368',
#   '2021-02-11 19:35:01.748369',
#   '160.237.156.115'),
#  (771,
#   'Mark Holmes',
#   'susanwagner@thompson.biz',
#   '17471 Gary Court',
#   'Susanstad',
#   'Minnesota',
#   'Jersey',
#   '688.519.7217x751',
#   'Day part mother court team develop wonder. Cold light want much white '
#   'court.\n'
#   'Worry tonight visit television house significant. Information research '
#   'population direction.',
#   '1928-04-09',
#   1238,
#   '2021-02-11 19:35:01.749406',
#   '2021-02-11 19:35:01.749407',
#   '42.211.159.213'),
#  (772,
#   'Emily Newton',
#   'tiffany91@phelps-macias.info',
#   '12553 Kevin Valleys Apt. 007',
#   'South Keithburgh',
#   'Tennessee',
#   'Saint Helena',
#   '189.108.9907x832',
#   'Onto reveal in important interest reveal fire million. Weight father '
#   'require policy discuss.',
#   '1914-05-22',
#   1794,
#   '2021-02-11 19:35:01.750311',
#   '2021-02-11 19:35:01.750313',
#   '174.60.121.144'),
#  (773,
#   'Jonathan Stafford',
#   'johnstonrenee@downs-west.org',
#   '506 Crosby Rest',
#   'Hubbardville',
#   'North Dakota',
#   'Lithuania',
#   '531.452.5038x80285',
#   'Role player minute attention dog they. Huge also sister away improve '
#   'hospital many.\n'
#   'Ground people source performance. Loss allow no. Price general phone until '
#   'general red whom.',
#   '1979-12-21',
#   2311,
#   '2021-02-11 19:35:01.751319',
#   '2021-02-11 19:35:01.751321',
#   '63.118.229.91'),
#  (774,
#   'Jennifer Frank',
#   'susangray@clark-poole.com',
#   '175 Jermaine Greens',
#   'Davidbury',
#   'Pennsylvania',
#   'Nauru',
#   '+1-859-836-8485x067',
#   'Front even east under left. Clearly glass situation a hope. Ever kid son '
#   'happy a.\n'
#   'Develop can decision than seek group town price. Need science room old '
#   'ahead consider game.',
#   '1990-09-08',
#   2118,
#   '2021-02-11 19:35:01.752267',
#   '2021-02-11 19:35:01.752268',
#   '173.87.35.160'),
#  (775,
#   'Brittany Dougherty',
#   'nwilkins@hotmail.com',
#   '736 Brandon Run',
#   'Port Sandraton',
#   'Delaware',
#   'Seychelles',
#   '(075)679-5687x456',
#   'Law surface go condition state stage. Black major fight data short. Must '
#   'rich record attention.\n'
#   'Support arrive notice too nation. Smile he usually color our reduce. Sound '
#   'nice care suddenly.',
#   '1907-04-08',
#   1973,
#   '2021-02-11 19:35:01.753030',
#   '2021-02-11 19:35:01.753031',
#   '219.219.184.112'),
#  (776,
#   'Jonathan Kelly',
#   'jasonlandry@yahoo.com',
#   '389 Meghan Alley Suite 798',
#   'Paynehaven',
#   'Rhode Island',
#   'Ireland',
#   '625.446.6025x787',
#   'Property probably discussion guess traditional. Medical trouble section.\n'
#   'Them charge article determine. Local maybe purpose finish road hair. Land '
#   'quickly century still.',
#   '1933-11-07',
#   2120,
#   '2021-02-11 19:35:01.753861',
#   '2021-02-11 19:35:01.753862',
#   '183.84.189.13'),
#  (777,
#   'Nicole Gonzalez',
#   'daniel71@evans.info',
#   '336 Jessica Inlet Apt. 313',
#   'Heathland',
#   'Washington',
#   'Puerto Rico',
#   '+1-027-639-1426x89738',
#   'Economy term inside realize. Story put explain house young detail never. '
#   'Some material recently try become.\n'
#   'Toward get even dream lay smile. Wife region town sense company agree '
#   'claim.',
#   '2009-02-21',
#   1516,
#   '2021-02-11 19:35:01.754853',
#   '2021-02-11 19:35:01.754855',
#   '68.198.38.76'),
#  (778,
#   'Sylvia Reed',
#   'melissawilliams@hernandez-hill.com',
#   '8317 Ramsey Loaf Apt. 922',
#   'North Erin',
#   'Maryland',
#   'Mexico',
#   '825-214-2616',
#   'Hair about sense term quality risk. Right the community may. Rise three '
#   'particularly often house show.\n'
#   'Five difficult green drop.',
#   '1915-09-18',
#   1674,
#   '2021-02-11 19:35:01.755922',
#   '2021-02-11 19:35:01.755923',
#   '126.94.63.160'),
#  (779,
#   'Tanya Curry',
#   'ayalawilliam@guzman.com',
#   '78954 Mooney Greens',
#   'New Dawnbury',
#   'Vermont',
#   'Libyan Arab Jamahiriya',
#   '001-676-341-4849x4656',
#   'Individual nothing party third start. Talk old whose physical side.',
#   '1937-06-04',
#   1366,
#   '2021-02-11 19:35:01.756846',
#   '2021-02-11 19:35:01.756848',
#   '198.127.2.25'),
#  (780,
#   'Vincent Harper',
#   'ortegakatie@hotmail.com',
#   '25152 Cory Harbors Apt. 051',
#   'Prattfort',
#   'Nebraska',
#   'Sweden',
#   '(899)933-6560',
#   'Trip area detail meeting cup performance continue artist. Drug son '
#   'character suffer sign.\n'
#   'Phone technology in. Dark walk this Mr blue son. At scientist claim same '
#   'true. Specific memory ground market.',
#   '1960-07-14',
#   2192,
#   '2021-02-11 19:35:01.757680',
#   '2021-02-11 19:35:01.757682',
#   '174.59.100.255'),
#  (781,
#   'Valerie Horn',
#   'timothycole@adams.com',
#   '731 Flynn Road Suite 993',
#   'Lake Melissaview',
#   'Maryland',
#   'Tokelau',
#   '148.116.5249',
#   'Dinner education if station. Vote smile red manage house build thank. '
#   'Action student alone should history Republican. Generation clearly success '
#   'from bill boy development.',
#   '1982-06-22',
#   2441,
#   '2021-02-11 19:35:01.758750',
#   '2021-02-11 19:35:01.758752',
#   '201.38.131.37'),
#  (782,
#   'Michael Rice',
#   'rileydennis@yahoo.com',
#   '79004 Suzanne Gateway Apt. 044',
#   'North Valeriefurt',
#   'Rhode Island',
#   'Cook Islands',
#   '7913762300',
#   'Save rise election body fast. From still dark tend issue crime she. Low Mrs '
#   'rather food whole medical little.\n'
#   'Three move none. Plant enough here Democrat quite society.',
#   '1971-02-19',
#   1305,
#   '2021-02-11 19:35:01.759559',
#   '2021-02-11 19:35:01.759560',
#   '184.3.236.100'),
#  (783,
#   'Ruth Lewis',
#   'ashleedeleon@jackson.com',
#   '5436 Tammy Summit Apt. 521',
#   'Brooksburgh',
#   'Nebraska',
#   'Paraguay',
#   '(095)537-6112x75479',
#   'Those management side. Education over over anyone ever month. Network still '
#   'but maybe establish.\n'
#   'Board school garden front our half. Become different drive large because '
#   'her. Explain return job late.',
#   '1954-12-29',
#   1504,
#   '2021-02-11 19:35:01.760561',
#   '2021-02-11 19:35:01.760563',
#   '7.233.226.37'),
#  (784,
#   'Jasmine Cunningham',
#   'deannaarellano@yahoo.com',
#   '117 Stephenson Meadow',
#   'Websterbury',
#   'Oregon',
#   'Finland',
#   '303-222-0610x38088',
#   'Establish score issue opportunity rest. Way middle realize customer pretty. '
#   'Difference live police. Exactly because science for would respond.',
#   '1956-12-14',
#   2466,
#   '2021-02-11 19:35:01.761357',
#   '2021-02-11 19:35:01.761358',
#   '27.193.24.91'),
#  (785,
#   'Lisa Johnson',
#   'alexis98@liu.com',
#   '333 Keller Summit',
#   'Port Willie',
#   'Oklahoma',
#   'Lebanon',
#   '848-411-3427',
#   'Perhaps wear me next ten against training. Quite seat cup sense two. Before '
#   'represent central scientist same citizen them.\n'
#   'Recognize start go.',
#   '1935-10-10',
#   1730,
#   '2021-02-11 19:35:01.762311',
#   '2021-02-11 19:35:01.762312',
#   '131.32.58.157'),
#  (786,
#   'Micheal Warren',
#   'taylor68@howard.com',
#   '21448 Ian Knoll Apt. 529',
#   'Port Richard',
#   'Texas',
#   'Kenya',
#   '(048)730-6272',
#   'Mention know involve. Same beat citizen her low win.\n'
#   'Enjoy suddenly consider arm rather.\n'
#   'Shoulder field stock former either feel.',
#   '1927-05-01',
#   1186,
#   '2021-02-11 19:35:01.763112',
#   '2021-02-11 19:35:01.763114',
#   '46.213.54.168'),
#  (787,
#   'Michael Burnett',
#   'cguerra@gmail.com',
#   '76596 Jefferson Courts Apt. 734',
#   'New John',
#   'Utah',
#   'Turkey',
#   '406.434.2335',
#   'Despite head ask number. Meeting house free draw. North house agent hot '
#   'society.',
#   '1930-09-25',
#   1348,
#   '2021-02-11 19:35:01.764586',
#   '2021-02-11 19:35:01.764589',
#   '179.242.118.6'),
#  (788,
#   'Jennifer Mooney',
#   'oramirez@hotmail.com',
#   '0296 Martin Cliff Suite 192',
#   'Mckinneyfort',
#   'North Dakota',
#   'Korea',
#   '392.979.3004',
#   'Those figure race for this hard. Today magazine game issue effect.',
#   '1961-11-21',
#   1907,
#   '2021-02-11 19:35:01.765683',
#   '2021-02-11 19:35:01.765686',
#   '208.253.35.181'),
#  (789,
#   'Tanya Johnson',
#   'jennifernelson@davidson.com',
#   '12430 Torres Squares Suite 722',
#   'South Teresa',
#   'Michigan',
#   'Sao Tome and Principe',
#   '(527)871-3189',
#   'Thank hour relationship include question challenge bill. Recognize ahead '
#   'important indicate.\n'
#   'Feel since south radio very always mission. Some environment perform.',
#   '1946-01-19',
#   1721,
#   '2021-02-11 19:35:01.766706',
#   '2021-02-11 19:35:01.766708',
#   '202.129.11.4'),
#  (790,
#   'Nicole Fields',
#   'ufarmer@gmail.com',
#   '60383 Adams Lock Apt. 813',
#   'Ayalabury',
#   'Arizona',
#   'Sao Tome and Principe',
#   '+1-790-277-0437x6159',
#   'Billion question while four. Allow single ball. Catch major item eat. Them '
#   'light oil subject hundred president how.',
#   '1919-05-24',
#   1622,
#   '2021-02-11 19:35:01.767510',
#   '2021-02-11 19:35:01.767512',
#   '164.155.111.154'),
#  (791,
#   'Kurt Bush',
#   'idennis@garcia.biz',
#   '5871 Brian Islands',
#   'East Stephen',
#   'Alaska',
#   'Djibouti',
#   '561.593.5208x4585',
#   'Air second attorney someone western run. White down toward. Natural head '
#   'weight song page notice.',
#   '1957-12-08',
#   1115,
#   '2021-02-11 19:35:01.768494',
#   '2021-02-11 19:35:01.768496',
#   '154.51.131.248'),
#  (792,
#   'Amy Kaufman',
#   'wilsonmark@yahoo.com',
#   '2461 Williams Lock',
#   'Lake Frank',
#   'Tennessee',
#   'Saint Vincent and the Grenadines',
#   '733.124.2775x96886',
#   'There audience cut bank. Evidence long ground wind next research back.\n'
#   'Line bag free tend issue camera. Word room plant huge few.',
#   '1978-06-15',
#   1454,
#   '2021-02-11 19:35:01.769282',
#   '2021-02-11 19:35:01.769283',
#   '124.100.190.36'),
#  (793,
#   'Jennifer Hawkins',
#   'kirkmark@gmail.com',
#   '2957 Brooks Mission',
#   'North Amy',
#   'Iowa',
#   'Macao',
#   '001-614-079-7339',
#   'Area card from candidate here any. Off kind indicate himself hot image.',
#   '1940-12-03',
#   1351,
#   '2021-02-11 19:35:01.770047',
#   '2021-02-11 19:35:01.770049',
#   '91.81.64.223'),
#  (794,
#   'Angela Edwards',
#   'heatherthomas@hotmail.com',
#   '416 Andrews Rapid',
#   'Brucestad',
#   'Massachusetts',
#   'Martinique',
#   '069.485.6712',
#   'Most picture dark personal practice. Gas thus behind. Bill late early '
#   'indicate customer identify its. Should reveal paper term.\n'
#   'Ok avoid year size enter.',
#   '1972-11-27',
#   1768,
#   '2021-02-11 19:35:01.770841',
#   '2021-02-11 19:35:01.770842',
#   '222.58.143.191'),
#  (795,
#   'Sonya Lang',
#   'vgonzalez@kidd.net',
#   '53560 Bryan Knoll Suite 444',
#   'Contrerasville',
#   'Missouri',
#   'Nigeria',
#   '(125)485-0670x1590',
#   'Attack three member charge. Fund stuff throughout gas later much.\n'
#   'Style left behind would. Group science may ago alone baby. Number action '
#   'paper process find building.',
#   '1957-08-04',
#   1478,
#   '2021-02-11 19:35:01.771733',
#   '2021-02-11 19:35:01.771734',
#   '168.115.216.5'),
#  (796,
#   'David Robinson',
#   'pittmantracy@yahoo.com',
#   '079 Miller Square Apt. 973',
#   'Henryborough',
#   'Delaware',
#   'Libyan Arab Jamahiriya',
#   '909-734-3901',
#   'Involve item affect future notice.\n'
#   'Interest remember cover city note scene table. Kid sure wait better weight. '
#   'Religious adult it protect.',
#   '1963-02-16',
#   2462,
#   '2021-02-11 19:35:01.772543',
#   '2021-02-11 19:35:01.772544',
#   '209.241.181.55'),
#  (797,
#   'Ashlee Chen',
#   'icordova@hotmail.com',
#   '58749 Lambert Gateway Apt. 397',
#   'North Mitchellburgh',
#   'Louisiana',
#   "Lao People's Democratic Republic",
#   '(312)401-9622x1412',
#   'Strong shake join someone modern. War benefit often meet article impact.\n'
#   'Say color right attention because morning push. Picture forward Mr city '
#   'she. Toward gas these month choose.',
#   '1986-09-09',
#   1573,
#   '2021-02-11 19:35:01.773274',
#   '2021-02-11 19:35:01.773276',
#   '192.251.55.138'),
#  (798,
#   'Robert Lee',
# ...
#   'Last bad pattern word speech artist. Represent national Republican very '
#   'opportunity quickly term. Born price student newspaper take gun animal. '
#   'Couple claim discuss make behavior.',
#   '1999-02-09',
#   1098,
#   '2021-02-11 19:35:01.925514',
#   '2021-02-11 19:35:01.925515',
#   '204.35.123.91'),
#  (964,
#   'Michaela Smith',
#   'bakermary@hotmail.com',
#   '70060 Davis Path Apt. 355',
#   'East Daniellechester',
#   'West Virginia',
#   "Lao People's Democratic Republic",
#   '+1-823-769-1807',
#   'Responsibility goal art role figure star Congress interest. Over yet will '
#   'size soon.\n'
#   'White bed wonder few against high. Test medical challenge long certain. '
#   'Least four least especially safe white.',
#   '1985-05-15',
#   1804,
#   '2021-02-11 19:35:01.926299',
#   '2021-02-11 19:35:01.926301',
#   '106.53.83.24'),
#  (965,
#   'Robert Sellers',
#   'richard52@king-hayes.org',
#   '1769 Martin Mission Suite 010',
#   'Nicholshaven',
#   'Massachusetts',
#   'Korea',
#   '756.143.8455',
#   'Lay establish interview who return I. Subject son sort happen. Station task '
#   'member wear stop play.',
#   '1925-05-14',
#   1778,
#   '2021-02-11 19:35:01.927226',
#   '2021-02-11 19:35:01.927228',
#   '108.94.168.147'),
#  (966,
#   'Darren Mccarthy',
#   'hughesgregory@rice-boone.org',
#   '495 Walsh Knoll Apt. 512',
#   'Hunterland',
#   'Rhode Island',
#   'San Marino',
#   '798.713.7309',
#   'Certain three affect those coach ground law call. Attention race economy '
#   'treat.\n'
#   'Prove take any spend Congress bad. Rest major Mrs fly natural evidence. '
#   'Since capital example only simple present.',
#   '2005-12-10',
#   2349,
#   '2021-02-11 19:35:01.928197',
#   '2021-02-11 19:35:01.928199',
#   '104.246.210.178'),
#  (967,
#   'Jeffrey Macdonald',
#   'heathjennifer@hotmail.com',
#   '565 Zachary Pine Suite 223',
#   'Alvarezberg',
#   'Vermont',
#   'Samoa',
#   '+1-605-295-1273x8530',
#   'Around treatment meet partner nothing final then. Evidence close size '
#   'season.\n'
#   'Democratic final what.',
#   '1929-06-25',
#   1670,
#   '2021-02-11 19:35:01.928994',
#   '2021-02-11 19:35:01.928995',
#   '186.125.211.57'),
#  (968,
#   'Joshua Williams',
#   'holmeskenneth@yahoo.com',
#   '7309 Jerry Ridges Apt. 754',
#   'New Sierra',
#   'Mississippi',
#   'Russian Federation',
#   '001-688-648-3650',
#   'Line democratic traditional teach within near hair. Enjoy between growth '
#   'represent eye in record. Interesting resource right sign.',
#   '1996-05-09',
#   2307,
#   '2021-02-11 19:35:01.929736',
#   '2021-02-11 19:35:01.929738',
#   '161.234.1.200'),
#  (969,
#   'Kimberly Mora',
#   'laura22@gmail.com',
#   '980 Smith Park',
#   'Samanthaborough',
#   'West Virginia',
#   'Japan',
#   '(594)075-1616',
#   'Behind available newspaper sound tend walk travel. Others need explain '
#   'sister trade medical.',
#   '1971-09-02',
#   2084,
#   '2021-02-11 19:35:01.930507',
#   '2021-02-11 19:35:01.930508',
#   '204.224.128.208'),
#  (970,
#   'Erin Avery',
#   'iray@scott-griffin.info',
#   '97684 Davis Mount Apt. 471',
#   'Foxmouth',
#   'Florida',
#   'Cocos (Keeling) Islands',
#   '407-095-9412x933',
#   'Year season find among wind. Why chance brother father whose born '
#   'attorney.\n'
#   'Between enough degree every exist. Face piece style before spend determine '
#   'you tend.',
#   '1977-07-22',
#   1871,
#   '2021-02-11 19:35:01.931448',
#   '2021-02-11 19:35:01.931449',
#   '208.74.38.195'),
#  (971,
#   'Ashley Carpenter',
#   'phillipperez@ramsey.biz',
#   '2494 Wright Garden',
#   'Kennethton',
#   'New York',
#   'Gabon',
#   '(268)435-2594x93125',
#   'Wind little personal box family attention. Computer wind head music mouth.\n'
#   'Sell seek road cause keep. Lay general body hotel enter again. Agreement '
#   'claim wall run miss activity price election.',
#   '1979-10-11',
#   1546,
#   '2021-02-11 19:35:01.932361',
#   '2021-02-11 19:35:01.932362',
#   '167.114.17.153'),
#  (972,
#   'John Salazar',
#   'hortonbeth@tate.biz',
#   '23757 Julie Lakes Suite 422',
#   'Lake Jonathan',
#   'New Mexico',
#   'Guadeloupe',
#   '698-702-5780',
#   'Later water car ball table improve. Statement sometimes bar follow chance '
#   'bank. American gun really step open bit range.\n'
#   'Majority wind south arrive through spring. Perform lead away listen.',
#   '1977-03-03',
#   1943,
#   '2021-02-11 19:35:01.933261',
#   '2021-02-11 19:35:01.933262',
#   '57.56.64.175'),
#  (973,
#   'Curtis Benson',
#   'fergusonjohn@carr.com',
#   '320 White Highway Suite 312',
#   'Gregfurt',
#   'Louisiana',
#   'Liechtenstein',
#   '781.217.3106x720',
#   'Both thought degree allow. Mouth else middle structure question develop '
#   'effect. Course adult a Congress traditional talk wish.\n'
#   'Affect agent nature sea. Employee prevent follow long voice.',
#   '1932-08-05',
#   2389,
#   '2021-02-11 19:35:01.934194',
#   '2021-02-11 19:35:01.934196',
#   '172.8.101.5'),
#  (974,
#   'Anthony Parker',
#   'courtney63@hotmail.com',
#   '642 Charles Meadows Apt. 719',
#   'Elijahmouth',
#   'Nebraska',
#   'Suriname',
#   '418.758.9349',
#   'Suffer say say relationship. Enter letter surface start.\n'
#   'Authority consider almost five trouble color. Good so center cost improve '
#   'mind news. Individual official be occur.',
#   '1929-07-02',
#   1779,
#   '2021-02-11 19:35:01.934915',
#   '2021-02-11 19:35:01.934917',
#   '112.169.234.194'),
#  (975,
#   'Brooke Herrera',
#   'dparker@hotmail.com',
#   '150 Heather Cliff Apt. 946',
#   'South Kimfort',
#   'Georgia',
#   'Cook Islands',
#   '952.922.5367',
#   'Single think day teacher significant. Side any feel democratic describe '
#   'spend. Can control deep.\n'
#   'Condition memory become lawyer fly. Have draw state agency.',
#   '1964-11-03',
#   1437,
#   '2021-02-11 19:35:01.935680',
#   '2021-02-11 19:35:01.935681',
#   '182.187.237.88'),
#  (976,
#   'Timothy Jones',
#   'ikennedy@perez.com',
#   '397 Franklin Trafficway Suite 322',
#   'Costaborough',
#   'Michigan',
#   'Barbados',
#   '001-168-649-9060',
#   'Wife join hard. Letter manager begin effect soon. Doctor base factor.\n'
#   'Tend almost marriage land we ball. Trip may quality pattern personal '
#   'suggest happy suddenly.',
#   '1916-11-19',
#   1301,
#   '2021-02-11 19:35:01.936548',
#   '2021-02-11 19:35:01.936549',
#   '216.222.66.199'),
#  (977,
#   'Donald Davis',
#   'turnerbrittany@gmail.com',
#   '36156 Beth Ferry',
#   'New Anthony',
#   'North Dakota',
#   'Bouvet Island (Bouvetoya)',
#   '622-792-2417x452',
#   'One myself until sound. Per own cover bank hair fall class occur.',
#   '1919-06-27',
#   2250,
#   '2021-02-11 19:35:01.937273',
#   '2021-02-11 19:35:01.937274',
#   '128.153.57.160'),
#  (978,
#   'Thomas Coleman',
#   'nicholsmichelle@mayo-lewis.com',
#   '15098 Jennifer Square',
#   'Mccoyshire',
#   'Michigan',
#   'Pitcairn Islands',
#   '+1-181-360-4970',
#   'Serious eye notice because population unit green. Trial ago child former. '
#   'Fast discover lead size marriage fear.',
#   '1983-05-06',
#   1751,
#   '2021-02-11 19:35:01.938237',
#   '2021-02-11 19:35:01.938239',
#   '14.21.146.175'),
#  (979,
#   'Carlos Gonzales',
#   'irodriguez@hotmail.com',
#   '32958 Gabriela Land Apt. 001',
#   'Port Michaeltown',
#   'New Hampshire',
#   'Portugal',
#   '+1-327-393-7424x123',
#   'Win myself better cultural full field who. Enough left which image present. '
#   'Subject role dog center me gas.',
#   '1907-07-11',
#   1268,
#   '2021-02-11 19:35:01.938959',
#   '2021-02-11 19:35:01.938960',
#   '79.211.129.65'),
#  (980,
#   'April Snow',
#   'mahoneydaniel@yahoo.com',
#   '702 Chen Loop Apt. 089',
#   'Natashaport',
#   'Mississippi',
#   'French Southern Territories',
#   '432.454.3291x8602',
#   'Create safe usually item. Enjoy modern some beautiful item.\n'
#   'Drive goal wide remember single history itself. Work anything realize up '
#   'war sign agency foot.',
#   '1986-06-17',
#   2284,
#   '2021-02-11 19:35:01.939738',
#   '2021-02-11 19:35:01.939740',
#   '63.65.104.220'),
#  (981,
#   'Alexander Warren',
#   'daviddavis@smith.biz',
#   '496 Evans Wells Suite 883',
#   'Weisston',
#   'Montana',
#   'Tuvalu',
#   '620-857-4644',
#   'Six throw loss participant account usually travel. Bill reality million '
#   'which late.\n'
#   'Increase stay describe fill. Report reflect me evidence.\n'
#   'Hand attention trial send hard energy eight huge.',
#   '2017-04-03',
#   2264,
#   '2021-02-11 19:35:01.941102',
#   '2021-02-11 19:35:01.941103',
#   '211.183.168.93'),
#  (982,
#   'Chelsea Rogers',
#   'grossdarlene@roman.info',
#   '496 Shawn Crossing',
#   'North Kenneth',
#   'Nevada',
#   'Saint Kitts and Nevis',
#   '491.057.1824x04990',
#   'Behavior cut before PM land performance figure.\n'
#   'Behavior identify put write bill whether. Nature painting response big. '
#   'Difference body interesting push source.',
#   '1970-12-16',
#   1942,
#   '2021-02-11 19:35:01.941993',
#   '2021-02-11 19:35:01.941994',
#   '185.253.129.90'),
#  (983,
#   'Colleen Owens',
#   'nicholascohen@brown.com',
#   '0921 Caitlin Freeway',
#   'Vasquezhaven',
#   'Maryland',
#   'Gabon',
#   '+1-058-227-9879x45471',
#   'Late meet development particular college owner help. Plan how must stock. '
#   'Section everything PM as partner two.',
#   '1925-01-12',
#   1721,
#   '2021-02-11 19:35:01.943035',
#   '2021-02-11 19:35:01.943037',
#   '55.22.178.102'),
#  (984,
#   'Nathan Gates',
#   'ocopeland@nielsen.com',
#   '5578 Joseph Shoal Suite 917',
#   'Lake Julie',
#   'Mississippi',
#   'Niger',
#   '486-108-9349x278',
#   'Meet fight little fact. Despite rest us least organization thank.\n'
#   'Theory our difference game half wait. Them theory science government '
#   'because. Remember television ball month keep.',
#   '1932-03-26',
#   2118,
#   '2021-02-11 19:35:01.944107',
#   '2021-02-11 19:35:01.944108',
#   '108.59.136.150'),
#  (985,
#   'Aaron Mayo',
#   'mackenziegarrison@cooke-silva.info',
#   '670 Edward Bridge Suite 846',
#   'Port Alan',
#   'New Hampshire',
#   'Romania',
#   '0327974601',
#   'Across glass read and tonight. Likely mouth share option travel woman '
#   'treat. President enter where letter small try money.',
#   '2012-06-26',
#   1085,
#   '2021-02-11 19:35:01.945078',
#   '2021-02-11 19:35:01.945079',
#   '153.209.94.138'),
#  (986,
#   'Caitlin Powell',
#   'davisrobert@yahoo.com',
#   '80119 Angela Harbors',
#   'North Josephmouth',
#   'Oklahoma',
#   'Ethiopia',
#   '640.448.6011x191',
#   'Front accept back investment likely agreement treat. Billion them ten '
#   'professional beat. Simple others change approach open despite child.\n'
#   'East he easy southern relate.',
#   '1909-11-02',
#   1566,
#   '2021-02-11 19:35:01.945842',
#   '2021-02-11 19:35:01.945843',
#   '80.226.241.211'),
#  (987,
#   'Justin Robinson',
#   'randolphdavid@hotmail.com',
#   '000 Susan Lights Apt. 596',
#   'Lake Francis',
#   'Ohio',
#   'Angola',
#   '(118)257-5723x004',
#   'Body PM again mission order individual late. Word ago whatever goal charge. '
#   'Expect board wish father lay why choose.\n'
#   'Result including person entire above detail.',
#   '1930-05-17',
#   2164,
#   '2021-02-11 19:35:01.946613',
#   '2021-02-11 19:35:01.946614',
#   '104.205.107.225'),
#  (988,
#   'Manuel Campbell',
#   'omayo@hotmail.com',
#   '866 Sims Circle Apt. 668',
#   'Port Samantha',
#   'Idaho',
#   'Malta',
#   '493.848.8279',
#   'Speech decade name fall machine man. Race building he. Statement sea best '
#   'machine.',
#   '1983-04-25',
#   1723,
#   '2021-02-11 19:35:01.947313',
#   '2021-02-11 19:35:01.947314',
#   '114.180.2.252'),
#  (989,
#   'Bradley Baker',
#   'rebeccabell@barnes-anderson.biz',
#   '042 Edwards Orchard Apt. 181',
#   'Douglasport',
#   'New Mexico',
#   'Sudan',
#   '(540)189-0023',
#   'Large tell charge like really all cut. Magazine can voice.\n'
#   'Thousand decide down. Develop effort new center area wife. Professional '
#   'system father which floor argue adult.',
#   '2002-09-25',
#   1253,
#   '2021-02-11 19:35:01.948308',
#   '2021-02-11 19:35:01.948310',
#   '173.113.129.139'),
#  (990,
#   'Brian Garrett',
#   'garciasara@wilson.com',
#   '42997 Sara Gardens',
#   'North Nathantown',
#   'Idaho',
#   'Cook Islands',
#   '556.439.4735x660',
#   'News dog check probably peace fall day tell. Exactly morning interview '
#   'choice debate society assume. Local remain step interest.',
#   '1974-09-05',
#   1764,
#   '2021-02-11 19:35:01.949351',
#   '2021-02-11 19:35:01.949352',
#   '179.146.84.117'),
#  (991,
#   'Jonathan Mccoy',
#   'fstevenson@hotmail.com',
#   '7421 Crawford Plaza',
#   'Port Franciscoborough',
#   'North Carolina',
#   'Slovakia (Slovak Republic)',
#   '(498)981-0527x504',
#   'Rule situation street since development party little thank. Perhaps girl '
#   'whatever yet.',
#   '1930-11-23',
#   1436,
#   '2021-02-11 19:35:01.950083',
#   '2021-02-11 19:35:01.950085',
#   '112.132.53.162'),
#  (992,
#   'Russell Pittman',
#   'chavezjose@yahoo.com',
#   '14544 Randy Parkways Suite 312',
#   'New Brucehaven',
#   'Rhode Island',
#   'Tonga',
#   '6094330115',
#   'Career gas laugh oil. Dog method politics white pull. Way support none '
#   'suggest. Major Congress travel accept.\n'
#   'Blood which treat argue. Successful nor truth accept across talk nor.',
#   '1985-01-06',
#   2088,
#   '2021-02-11 19:35:01.950978',
#   '2021-02-11 19:35:01.950980',
#   '30.205.245.86'),
#  (993,
#   'Ms. Kristi Carroll',
#   'benjamincopeland@yahoo.com',
#   '19308 Boone Island',
#   'Jacksonberg',
#   'Nevada',
#   'Lesotho',
#   '(756)113-4973x930',
#   'Everyone human speak. Whose crime billion garden operation ahead medical. '
#   'Executive chance turn prepare.\n'
#   'Across race stock recently. Memory green tax style she plant.',
#   '2016-11-19',
#   1055,
#   '2021-02-11 19:35:01.951840',
#   '2021-02-11 19:35:01.951842',
#   '179.85.200.215'),
#  (994,
#   'Catherine Cortez',
#   'codybarron@stewart.net',
#   '9473 Osborne Mission Apt. 663',
#   'East Brian',
#   'Virginia',
#   'Latvia',
#   '466.449.6047x5817',
#   'A southern wait service.\n'
#   'Include Republican result system thousand century. By they thus.',
#   '1947-03-12',
#   1463,
#   '2021-02-11 19:35:01.952889',
#   '2021-02-11 19:35:01.952890',
#   '215.170.101.29'),
#  (995,
#   'Alicia Dalton',
#   'tjoyce@yahoo.com',
#   '34942 Brian Shoal',
#   'North Melissa',
#   'Florida',
#   'Iraq',
#   '5864597165',
#   'Get say short suddenly office activity pick though. Mouth politics free day '
#   'hear.\n'
#   'Election figure heart door true fast. Can maybe season in network detail. '
#   'School sign most car catch.',
#   '1970-12-27',
#   1195,
#   '2021-02-11 19:35:01.953627',
#   '2021-02-11 19:35:01.953629',
#   '145.193.142.136'),
#  (996,
#   'Jessica Byrd',
#   'igarcia@gmail.com',
#   '465 Lee Rue',
#   'East Beckymouth',
#   'New York',
#   'Svalbard & Jan Mayen Islands',
#   '+1-269-658-4380x54572',
#   'They despite project fear beyond control level. Method late official '
#   'decision over myself child. Training boy city know. Some fear police full '
#   'be admit others.',
#   '1990-09-11',
#   1617,
#   '2021-02-11 19:35:01.954435',
#   '2021-02-11 19:35:01.954436',
#   '82.247.38.135'),
#  (997,
#   'Daniel Peterson',
#   'davisbrian@yahoo.com',
#   '1746 Brian Bridge Suite 147',
#   'Alexanderfort',
#   'Florida',
#   'New Zealand',
#   '001-150-970-5895x0893',
#   'Table reveal some consumer letter. Alone instead either bank sound do '
#   'experience.\n'
#   'Nothing house how pass move president. Similar well let local fill couple '
#   'this. People long sure need.',
#   '1947-07-31',
#   1701,
#   '2021-02-11 19:35:01.955266',
#   '2021-02-11 19:35:01.955267',
#   '192.126.245.205'),
#  (998,
#   'Samuel Townsend',
#   'taylorlee@hotmail.com',
#   '2336 Sarah Fields',
#   'West Jamesmouth',
#   'Massachusetts',
#   'Guinea-Bissau',
#   '+1-304-042-8360x40995',
#   'Appear individual reason accept seem. Southern effort as teacher item.',
#   '1957-03-02',
#   1730,
#   '2021-02-11 19:35:01.956017',
#   '2021-02-11 19:35:01.956018',
#   '196.113.204.222'),
#  (999,
#   'Jesus Vega',
#   'curtis78@gmail.com',
#   '464 Hooper Ford',
#   'North Nicoleland',
#   'Nevada',
#   'Zambia',
#   '110.950.9303x63588',
#   'Class plant above story carry. Few president hard memory wind need '
#   'provide.\n'
#   'Politics join hear while. Blue station manage treat true every dinner fine. '
#   'Imagine wife believe American interesting true.',
#   '1981-02-04',
#   2358,
#   '2021-02-11 19:35:01.956756',
#   '2021-02-11 19:35:01.956757',
#   '202.7.27.180'),
#  (1000,
#   'Candace Bradley',
#   'coopergrant@daniels.biz',
#   '04685 Daniel Vista',
#   'Port Kellybury',
#   'New Mexico',
#   'Cameroon',
#   '461.353.2281x536',
#   'Money close yet imagine. Without investment unit.',
#   '1978-06-08',
#   1175,
#   '2021-02-11 19:35:01.957790',
#   '2021-02-11 19:35:01.957791',
#   '154.37.225.64')]

# %% [markdown]
# Finally, the last step,
# Using the code block below, combined with what you have learned above, and the Lecture notes,
# Craft a SQL Query that will return the `name` of no more than `20` `people` with a `heatmap` greater than `1500`

# %%
import sqlite3
from pprint import pprint
#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

selectStatement = """SELECT * FROM people
WHERE heatmap > 1500
LIMIT 20 """

myCursor.execute(selectStatement)
results = myCursor.fetchall()
pprint(results)
# Out:
# [(2,
#   'Tiffany Harvey',
#   'fwhite@gmail.com',
#   '051 Marquez Hill',
#   'Port Christopher',
#   'Oregon',
#   'Taiwan',
#   '148.121.3403',
#   'Out interesting whatever direction. Trade media according avoid research '
#   'serious smile. Finish fill speech record them.',
#   '1974-09-08',
#   1962,
#   '2021-02-11 19:35:01.031086',
#   '2021-02-11 19:35:01.031088',
#   '139.185.71.15'),
#  (3,
#   'Brenda Bass',
#   'ljackson@gmail.com',
#   '609 Mejia Underpass',
#   'New Tracyland',
#   'Michigan',
#   'Vanuatu',
#   '001-045-147-9440x991',
#   'Everybody very hand enjoy foot.\n'
#   'Yet make before mother. Admit represent rather task here necessary anyone.\n'
#   'Successful action within raise stop. Foreign figure everyone name appear '
#   'through tell.',
#   '1996-02-19',
#   2261,
#   '2021-02-11 19:35:01.032130',
#   '2021-02-11 19:35:01.032133',
#   '147.90.9.137'),
#  (4,
#   'Charles Mccullough',
#   'brandonbrown@yahoo.com',
#   '04500 Tony Expressway',
#   'South Lynn',
#   'Maine',
#   'Mali',
#   '835.596.6189',
#   'Realize could others purpose. Among Republican hotel red.\n'
#   'Early would nature traditional. Smile or skin onto pass front win build. '
#   'Expert wide debate even so.',
#   '1906-11-06',
#   1976,
#   '2021-02-11 19:35:01.033039',
#   '2021-02-11 19:35:01.033040',
#   '215.120.221.136'),
#  (5,
#   'Rachel Shelton',
#   'jodyjenkins@hotmail.com',
#   '718 Mclaughlin Keys',
#   'Davidshire',
#   'Tennessee',
#   'Italy',
#   '074-228-9521',
#   'Small month company kid surface. Design dog member yes really. Network '
#   'product win tell next.\n'
#   'Still almost consumer southern. Member throughout suddenly agreement letter '
#   'whatever.',
#   '1968-05-10',
#   2273,
#   '2021-02-11 19:35:01.033866',
#   '2021-02-11 19:35:01.033867',
#   '145.234.186.236'),
#  (6,
#   'Jill Little',
#   'morgan84@yahoo.com',
#   '905 Michael Parks Suite 659',
#   'South Tonyamouth',
#   'Michigan',
#   'Paraguay',
#   '(806)261-1951x8109',
#   'Cut mother person success single product company. Trip early PM already '
#   'type event. Relationship church ball support again.',
#   '1944-10-13',
#   2371,
#   '2021-02-11 19:35:01.034605',
#   '2021-02-11 19:35:01.034606',
#   '26.102.56.93'),
#  (8,
#   'Jennifer Tran',
#   'sean80@alexander.com',
#   '5850 Shah Court Apt. 125',
#   'New Andrew',
#   'Kentucky',
#   'Korea',
#   '(098)396-6560x957',
#   'Chair agree accept fall black. Store forward actually dream certainly free '
#   'computer radio. Itself international interview section seek much.',
#   '1966-11-18',
#   2482,
#   '2021-02-11 19:35:01.036226',
#   '2021-02-11 19:35:01.036227',
#   '196.121.193.193'),
#  (9,
#   'William Baker',
#   'teresa30@gmail.com',
#   '317 Tyler Station',
#   'West Martin',
#   'Illinois',
#   'Taiwan',
#   '(858)827-2041x1728',
#   'Nothing team model seat staff. Sport dream cost often strong beyond '
#   'southern.\n'
#   'Wear chair same evidence. Finally experience them event.\n'
#   'Keep those wish. Per past friend life point all.',
#   '2019-02-22',
#   1936,
#   '2021-02-11 19:35:01.036937',
#   '2021-02-11 19:35:01.036938',
#   '123.0.57.71'),
#  (12,
#   'Maria Francis',
#   'kimberlymoss@morse-miller.com',
#   '309 Michael Mountains Apt. 320',
#   'North Karen',
#   'Kansas',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   '9284097651',
#   'Population write billion person inside day society. City hear agree take '
#   'lawyer hundred. Stand time week dog live man family manage.',
#   '2010-03-03',
#   1532,
#   '2021-02-11 19:35:01.039573',
#   '2021-02-11 19:35:01.039575',
#   '88.137.118.120'),
#  (13,
#   'Scott Martinez',
#   'cnelson@weaver-johnson.com',
#   '04213 Natasha Burgs Apt. 192',
#   'Johnstonville',
#   'Oklahoma',
#   'Mozambique',
#   '130.814.8031',
#   'My late certainly not the five film. Approach behavior better impact.\n'
#   'Southern consider thus charge interest enjoy feel. Possible specific nor '
#   'life on. Left director participant arm cold bad heart.',
#   '1963-10-03',
#   1650,
#   '2021-02-11 19:35:01.040584',
#   '2021-02-11 19:35:01.040586',
#   '17.235.190.93'),
#  (14,
#   'Martin Evans',
#   'singletonshane@wiley.org',
#   '5888 Alexander Mountains',
#   'New Robertfort',
#   'Georgia',
#   'Nauru',
#   '001-684-353-4945x520',
#   'Word seat theory both stay yes. Less start away which compare.\n'
#   'Those take country couple design when. New activity ten vote never seven '
#   'state. Majority good herself off upon tree candidate.',
#   '2016-10-07',
#   1752,
#   '2021-02-11 19:35:01.041615',
#   '2021-02-11 19:35:01.041616',
#   '182.196.47.159'),
#  (16,
#   'Zachary Russell',
#   'deanna44@contreras.com',
#   '7022 Fernandez Squares Apt. 813',
#   'Steelemouth',
#   'Colorado',
#   'New Caledonia',
#   '+1-417-246-4723x045',
#   'Method dog push everybody. Hand radio explain occur try. Else sound ground '
#   'modern human surface campaign.\n'
#   'Action number detail discover. Pressure argue create stand Congress entire.',
#   '1959-03-12',
#   1670,
#   '2021-02-11 19:35:01.043358',
#   '2021-02-11 19:35:01.043359',
#   '222.141.165.100'),
#  (17,
#   'Dennis Craig',
#   'david03@yahoo.com',
#   '656 Charles Row',
#   'North Tonya',
#   'Texas',
#   'Marshall Islands',
#   '9131030849',
#   'Majority put loss physical worry likely. Accept fill else deep various few. '
#   'Hear ability voice remain candidate sit.\n'
#   'Design lead keep smile.\n'
#   'Challenge clearly your also police think every.',
#   '1981-05-30',
#   2416,
#   '2021-02-11 19:35:01.044055',
#   '2021-02-11 19:35:01.044056',
#   '59.65.148.26'),
#  (18,
#   'Donna Hartman',
#   'donnabrewer@yahoo.com',
#   '83172 White Crossing Apt. 430',
#   'Mooreshire',
#   'Texas',
#   'Haiti',
#   '001-696-810-5199x2686',
#   'Nearly entire upon process.\n'
#   'Choose entire notice leg near change ground cultural. Bar claim get author '
#   'however last yet. Final participant song sort adult coach arrive thank.',
#   '1975-04-07',
#   1706,
#   '2021-02-11 19:35:01.044875',
#   '2021-02-11 19:35:01.044876',
#   '70.128.60.134'),
#  (19,
#   'Darryl Stewart',
#   'garciajohn@yahoo.com',
#   '90246 Jeremy Fords Apt. 589',
#   'Cooleyfurt',
#   'Illinois',
#   'Jersey',
#   '(772)517-8915x785',
#   'Stock on perform statement. Type share line born.\n'
#   'Study bar go ground drop general. Side discussion arrive team.\n'
#   'Price ago both my work may special. Across put vote budget. Peace modern '
#   'pretty man.',
#   '1950-02-22',
#   2058,
#   '2021-02-11 19:35:01.045705',
#   '2021-02-11 19:35:01.045706',
#   '108.10.25.1'),
#  (20,
#   'Katrina Young',
#   'kristaboyd@hotmail.com',
#   '161 Denise Wall',
#   'South Kimberlyfurt',
#   'New Mexico',
#   'Argentina',
#   '(771)627-5124',
#   'Matter bar treat carry. Natural force attack majority.\n'
#   'Cause fly employee face interview data life. Rather along pull work.',
#   '1924-04-02',
#   2463,
#   '2021-02-11 19:35:01.046438',
#   '2021-02-11 19:35:01.046440',
#   '169.52.95.3'),
#  (21,
#   'Jessica Rowland MD',
#   'john15@price.com',
#   '212 Williams Lakes Suite 415',
#   'Lake Donna',
#   'Mississippi',
#   'Germany',
#   '(644)725-7034x74363',
#   'Wrong put catch tell crime down son. Owner part all finish. Work protect '
#   'religious term eye manage. Mission matter later everybody.',
#   '1943-08-10',
#   2055,
#   '2021-02-11 19:35:01.047430',
#   '2021-02-11 19:35:01.047431',
#   '70.174.136.108'),
#  (23,
#   'Brian Stewart',
#   'edwardsbethany@gmail.com',
#   '295 Nunez Vista Apt. 700',
#   'South Rebekahstad',
#   'Kentucky',
#   'Ecuador',
#   '001-320-818-5874x3880',
#   'Size clearly particularly type message. Everybody interview alone college '
#   'night hospital success. Base hit mother particular simply take wonder sort.',
#   '1968-07-25',
#   2497,
#   '2021-02-11 19:35:01.049069',
#   '2021-02-11 19:35:01.049070',
#   '186.61.187.86'),
#  (24,
#   'Mrs. Natalie Wade MD',
#   'debramcdaniel@stokes.com',
#   '40111 Guzman Mission Apt. 719',
#   'Elizabethmouth',
#   'Ohio',
#   'Iran',
#   '8589768217',
#   'Dark stand remain PM several poor mention agency. Society occur water '
#   'positive assume. Rate whether fight meeting give effort response.\n'
#   'Raise relate north play vote. Huge deep mention some.',
#   '1977-10-26',
#   2499,
#   '2021-02-11 19:35:01.050137',
#   '2021-02-11 19:35:01.050138',
#   '83.242.152.40'),
#  (25,
#   'Kelly Tucker',
#   'rebeccawilliamson@stone-watts.com',
#   '32117 Taylor Fords Suite 215',
#   'New Markstad',
#   'New Jersey',
#   'Niue',
#   '+1-334-163-4689x7837',
#   'Including say there glass laugh. Fast artist yard role food it. Development '
#   'finish community American.\n'
#   'Economic positive service over early. Brother try north letter civil report '
#   'president.',
#   '1931-09-10',
#   1503,
#   '2021-02-11 19:35:01.051130',
#   '2021-02-11 19:35:01.051131',
#   '30.182.142.158'),
#  (26,
#   'Kristopher Johnson',
#   'heatherbrown@hotmail.com',
#   '1806 Breanna Wells',
#   'Port Terryfort',
#   'Alaska',
#   'Macao',
#   '3357414232',
#   'Include Congress agency price common region environmental commercial. Once '
#   'end maybe item. Later decade become position notice while community.\n'
#   'Job kitchen especially friend gun.',
#   '1949-06-22',
#   2117,
#   '2021-02-11 19:35:01.051877',
#   '2021-02-11 19:35:01.051879',
#   '6.20.46.144')]

# %% [markdown]
# Your submission will contain, as usual, a link to your completed colab notebook, but in addition to that, you will download a copy of your social_network.db file and upload it to D2L. To download the file, right click it from the Files menu on the left of the Notebook.
